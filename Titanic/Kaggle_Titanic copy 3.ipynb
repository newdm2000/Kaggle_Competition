# %%
import pandas as pd
import numpy as np

train = pd.read_csv('input/train.csv')
test = pd.read_csv('input/test.csv')

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.shape
# Out:
# (891, 12)

# %%
test.shape
# Out:
# (418, 11)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
def bar_chart(feature):
    survived = train[train['Survived']==1][feature].value_counts()
    dead = train[train['Survived']==0][feature].value_counts()
    df = pd.DataFrame([survived, dead])
    df.index = ['Survived', 'Dead']
    df.plot(kind='bar', stacked=True, figsize=(10,5))

# %%
bar_chart('Sex')

# %%
bar_chart('SibSp')

# %%
bar_chart('Parch')

# %%
bar_chart('Pclass')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %% [markdown]
# ticket delete
# name mr, miss, mrs
# age nan:name mean 0~3
# embarked 0,1,2
# cabin delete
# sipsp + parch
# sex 0,1
# fare ~5, 5~10, 10~17, 17~30, 30~77, 77~

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
bar_chart('Embarked')

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()

# %%
train_test_set = [train, test]

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
for dataset in train_test_set:
    dataset['Title'] = dataset['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
    dataset['First_Name'] = dataset['Name'].str.extract('([A-Za-z\-]+)\, ', expand=False)
    
title_mapping = {"Mr": 0, "Miss": 1, "Mrs": 2, 
                 "Master": 3, "Dr": 3, "Rev": 3, "Col": 3, "Major": 3, "Mlle": 3,"Countess": 3,
                 "Ms": 3, "Lady": 3, "Jonkheer": 3, "Don": 3, "Dona" : 3, "Mme": 3,"Capt": 3,"Sir": 3 }

for dataset in train_test_set:
    dataset['Title'] = dataset['Title'].map(title_mapping)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title First_Name
# 0      0         A/5 21171   7.2500   NaN        S      0     Braund
# 1      0          PC 17599  71.2833   C85        C      2    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S      1  Heikkinen
# ...

# %%
name_list = np.concatenate((train["First_Name"], test["First_Name"]), axis=0)
class_name = np.unique(name_list)
first_name = train["First_Name"]
group = []
for i in range(len(first_name)):
    for j in range(len(class_name)):
        if first_name[i] == class_name[j]:
            group.append(j)


train["group"] = np.array(group)
group = []

first_name = test["First_Name"]
for i in range(len(first_name)):
    for j in range(len(class_name)):
        if first_name[i] == class_name[j]:
            group.append(j)
test["group"] = np.array(group)

# %%
train.drop('Name', axis=1, inplace=True)
test.drop('Name', axis=1, inplace=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Title First_Name  group
# 0         A/5 21171   7.2500   NaN        S      0     Braund    100
# 1          PC 17599  71.2833   C85        C      2    Cumings    190
# 2  STON/O2. 3101282   7.9250   NaN        S      1  Heikkinen    339
# 3            113803  53.1000  C123        S      2   Futrelle    276
# 4            373450   8.0500   NaN        S      0      Allen     15

# %%
sex_mapping = {"male": 0, "female": 1}
for dataset in train_test_set:
    dataset['Sex'] = dataset['Sex'].map(sex_mapping)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  22.0      1      0         A/5 21171
# 1            2         1       1    1  38.0      1      0          PC 17599
# 2            3         1       3    1  26.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  35.0      1      0            113803
# 4            5         0       3    0  35.0      0      0            373450
#
#       Fare Cabin Embarked  Title First_Name  group
# 0   7.2500   NaN        S      0     Braund    100
# 1  71.2833   C85        C      2    Cumings    190
# 2   7.9250   NaN        S      1  Heikkinen    339
# 3  53.1000  C123        S      2   Futrelle    276
# 4   8.0500   NaN        S      0      Allen     15

# %%
train["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
em_mapping = {"S":0, "C":1, "Q":2}
for dataset in train_test_set:
    dataset['Embarked'] = dataset['Embarked'].map(em_mapping)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  22.0      1      0         A/5 21171
# 1            2         1       1    1  38.0      1      0          PC 17599
# 2            3         1       3    1  26.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  35.0      1      0            113803
# 4            5         0       3    0  35.0      0      0            373450
#
#       Fare Cabin  Embarked  Title First_Name  group
# 0   7.2500   NaN       0.0      0     Braund    100
# 1  71.2833   C85       1.0      2    Cumings    190
# 2   7.9250   NaN       0.0      1  Heikkinen    339
# 3  53.1000  C123       0.0      2   Futrelle    276
# 4   8.0500   NaN       0.0      0      Allen     15

# %%
train.drop('Ticket', axis=1, inplace=True)
test.drop('Ticket', axis=1, inplace=True)

train.drop('Cabin', axis=1, inplace=True)
test.drop('Cabin', axis=1, inplace=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  \
# 0            1         0       3    0  22.0      1      0   7.2500       0.0
# 1            2         1       1    1  38.0      1      0  71.2833       1.0
# 2            3         1       3    1  26.0      0      0   7.9250       0.0
# 3            4         1       1    1  35.0      1      0  53.1000       0.0
# 4            5         0       3    0  35.0      0      0   8.0500       0.0
#
#    Title First_Name  group
# 0      0     Braund    100
# 1      2    Cumings    190
# 2      1  Heikkinen    339
# 3      2   Futrelle    276
# 4      0      Allen     15

# %%
bins = [-1, 5, 10, 17, 30, 77, 1000]
label = [0, 1, 2, 3, 4, 5]
for dataset in train_test_set:
    dataset['Fare'] = pd.cut(dataset['Fare'], bins=bins, labels=label).cat.codes

# %%
train["Fare"].fillna(train.groupby("Pclass")["Fare"].transform("mean"), inplace=True)
test["Fare"].fillna(test.groupby("Pclass")["Fare"].transform("mean"), inplace=True)

train["Fare"] = (train["Fare"] - train["Fare"].mean())/train["Fare"].std()
test["Fare"] = (test["Fare"] - test["Fare"].mean())/test["Fare"].std()

# %%
train.head(30)
# Out:
#     PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Fare  \
# 0             1         0       3    0  22.0      1      0 -0.995802
# 1             2         1       1    1  38.0      1      0  1.118399
# 2             3         1       3    1  26.0      0      0 -0.995802
# 3             4         1       1    1  35.0      1      0  1.118399
# 4             5         0       3    0  35.0      0      0 -0.995802
# 5             6         0       3    0   NaN      0      0 -0.995802
# 6             7         0       1    0  54.0      0      0  1.118399
# 7             8         0       3    0   2.0      3      1  0.413665
# 8             9         1       3    1  27.0      0      2 -0.291068
# 9            10         1       2    1  14.0      1      0  1.118399
# 10           11         1       3    1   4.0      1      1 -0.291068
# 11           12         1       1    1  58.0      0      0  0.413665
# 12           13         0       3    0  20.0      0      0 -0.995802
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    int64
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
#  8   Embarked     889 non-null    float64
#  9   Title        891 non-null    int64
#  10  First_Name   891 non-null    object
#  11  group        891 non-null    int32
# dtypes: float64(3), int32(1), int64(7), object(1)
# memory usage: 80.2+ KB

# %%
train["Age"].fillna(train.groupby("Title")["Age"].transform("mean"), inplace=True)
test["Age"].fillna(train.groupby("Title")["Age"].transform("mean"), inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    int64
#  4   Age          891 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
#  8   Embarked     889 non-null    float64
#  9   Title        891 non-null    int64
#  10  First_Name   891 non-null    object
#  11  group        891 non-null    int32
# dtypes: float64(3), int32(1), int64(7), object(1)
# memory usage: 80.2+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Sex          418 non-null    int64
#  3   Age          418 non-null    float64
#  4   SibSp        418 non-null    int64
#  5   Parch        418 non-null    int64
#  6   Fare         418 non-null    float64
#  7   Embarked     418 non-null    int64
#  8   Title        418 non-null    int64
#  9   First_Name   418 non-null    object
#  10  group        418 non-null    int32
# dtypes: float64(2), int32(1), int64(7), object(1)
# memory usage: 34.4+ KB

# %%
import random
train["Embarked"].fillna(random.randint(0, 2), inplace=True)
test["Embarked"].fillna(random.randint(0, 2), inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    int64
#  4   Age          891 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
#  8   Embarked     891 non-null    float64
#  9   Title        891 non-null    int64
#  10  First_Name   891 non-null    object
#  11  group        891 non-null    int32
# dtypes: float64(3), int32(1), int64(7), object(1)
# memory usage: 80.2+ KB

# %%
train["FamilySize"] = train["SibSp"] + train["Parch"] + 1
test["FamilySize"] = test["SibSp"] + test["Parch"] + 1

# %%
'''test["Age"] = (test["Age"] - train["Age"].mean())/train["Age"].std()
train["Age"] = (train["Age"] - train["Age"].mean())/train["Age"].std()

test["Pclass"] = (test["Pclass"] - train["Pclass"].mean())/train["Pclass"].std()
train["Pclass"] = (train["Pclass"] - train["Pclass"].mean())/train["Pclass"].std()

test["Sex"] = (test["Sex"] - train["Sex"].mean())/train["Sex"].std()
train["Sex"] = (train["Sex"] - train["Sex"].mean())/train["Sex"].std()

test["Embarked"] = (test["Embarked"] - train["Embarked"].mean())/train["Embarked"].std()
train["Embarked"] = (train["Embarked"] - train["Embarked"].mean())/train["Embarked"].std()

test["Title"] = (test["Title"] - train["Title"].mean())/train["Title"].std()
train["Title"] = (train["Title"] - train["Title"].mean())/train["Title"].std()

test["FamilySize"] = (test["FamilySize"] - train["FamilySize"].mean())/train["FamilySize"].std()
train["FamilySize"] = (train["FamilySize"] - train["FamilySize"].mean())/train["FamilySize"].std()

test["group"] = (test["group"] - train["group"].mean())/train["group"].std()
train["group"] = (train["group"] - train["group"].mean())/train["group"].std()'''
# Out:
# 'test["Age"] = (test["Age"] - train["Age"].mean())/train["Age"].std()\ntrain["Age"] = (train["Age"] - train["Age"].mean())/train["Age"].std()\n\ntest["Pclass"] = (test["Pclass"] - train["Pclass"].mean())/train["Pclass"].std()\ntrain["Pclass"] = (train["Pclass"] - train["Pclass"].mean())/train["Pclass"].std()\n\ntest["Sex"] = (test["Sex"] - train["Sex"].mean())/train["Sex"].std()\ntrain["Sex"] = (train["Sex"] - train["Sex"].mean())/train["Sex"].std()\n\ntest["Embarked"] = (test["Embarked"] - train["Embarked"].mean())/train["Embarked"].std()\ntrain["Embarked"] = (train["Embarked"] - train["Embarked"].mean())/train["Embarked"].std()\n\ntest["Title"] = (test["Title"] - train["Title"].mean())/train["Title"].std()\ntrain["Title"] = (train["Title"] - train["Title"].mean())/train["Title"].std()\n\ntest["FamilySize"] = (test["FamilySize"] - train["FamilySize"].mean())/train["FamilySize"].std()\ntrain["FamilySize"] = (train["FamilySize"] - train["FamilySize"].mean())/train["FamilySize"].std()\
# ...

# %%
features_drop = ['SibSp', 'Parch']
train = train.drop(features_drop, axis=1)
test = test.drop(features_drop, axis=1)
train = train.drop(['PassengerId'], axis=1)

# %%
train_data = train.drop('Survived', axis=1)
target = train['Survived']
train_data = train_data.drop('First_Name', axis=1)
test_data = test.drop("First_Name", axis=1)

train_data.shape, target.shape, test_data.shape
# Out:
# ((891, 8), (891,), (418, 9))

# %%
train_data.head(10)
# Out:
#    Pclass  Sex       Age      Fare  Embarked  Title  group  FamilySize
# 0       3    0  22.00000 -0.995802       0.0      0    100           2
# 1       1    1  38.00000  1.118399       1.0      2    190           2
# 2       3    1  26.00000 -0.995802       0.0      1    339           1
# 3       1    1  35.00000  1.118399       0.0      2    276           2
# 4       3    0  35.00000 -0.995802       0.0      0     15           1
# 5       3    0  32.36809 -0.995802       2.0      0    551           1
# 6       1    0  54.00000  1.118399       0.0      0    511           1
# 7       3    0   2.00000  0.413665       0.0      3    612           5
# 8       3    1  27.00000 -0.291068       0.0      2    391           3
# 9       2    1  14.00000  1.118399       1.0      2    574           2

# %%
test_data.head(10)
# Out:
#    PassengerId  Pclass  Sex   Age      Fare  Embarked  Title  group  \
# 0          892       3    0  34.5 -1.004123         2      0    410
# 1          893       3    1  47.0 -1.004123         0      2    850
# 2          894       2    0  62.0 -1.004123         2      0    567
# 3          895       3    0  27.0 -1.004123         0      0    858
# 4          896       3    1  22.0 -0.295131         0      2    352
# 5          897       3    0  14.0 -1.004123         0      0    788
# 6          898       3    1  30.0 -1.004123         2      1    172
# 7          899       2    0  26.0  0.413862         0      0    120
# 8          900       3    1  18.0 -1.004123         1      2      5
# 9          901       3    0  21.0  0.413862         0      0    203
#
#    FamilySize
# 0           1
# 1           2
# 2           1
# 3           1
# 4           3
# 5           1
# 6           1
# 7           3
# 8           1
# 9           3

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(train.corr(), linewidths=0.01, square=True,
            annot=True, cmap=plt.cm.viridis, linecolor="white")
plt.title('Correlation between features')
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

import numpy as np

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

import numpy as np

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %%
clf = KNeighborsClassifier(n_neighbors = 13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.52222222 0.65168539 0.65168539 0.56179775 0.61797753 0.60674157
#  0.62921348 0.60674157 0.57303371 0.57303371]

# %%
# kNN Score
round(np.mean(score)*100, 2)
# Out:
# 59.94

# %%
clf = DecisionTreeClassifier()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.75555556 0.7752809  0.76404494 0.80898876 0.75280899 0.79775281
#  0.78651685 0.75280899 0.78651685 0.75280899]

# %%
# decision tree Score
round(np.mean(score)*100, 2)
# Out:
# 77.33

# %%
clf = RandomForestClassifier(n_estimators=13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.83333333 0.84269663 0.84269663 0.82022472 0.82022472 0.85393258
#  0.80898876 0.80898876 0.7752809  0.83146067]

# %%
# Random Forest Score
round(np.mean(score)*100, 2)
# Out:
# 82.38

# %%
clf = LogisticRegression()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.8        0.78651685 0.80898876 0.79775281 0.7752809  0.82022472
#  0.82022472 0.83146067 0.80898876 0.83146067]
# C:\Users\acsl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\acsl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
# ...

# %%
round(np.mean(score)*100, 2)
# Out:
# 80.81

# %%
clf = SVC()
clf.fit(train_data, target)

test_data = test_data.drop("PassengerId", axis=1).copy()
prediction = clf.predict(test_data)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
train_x, val_x, train_y, val_y = train_test_split(train_data, target, test_size=0.1, random_state=1)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error

my_predictions = {}
my_pred = None
my_actual = None
my_name = None

colors = ['r', 'c', 'm', 'y', 'k', 'khaki', 'teal', 'orchid', 'sandybrown',
          'greenyellow', 'dodgerblue', 'deepskyblue', 'rosybrown', 'firebrick',
          'deeppink', 'crimson', 'salmon', 'darkred', 'olivedrab', 'olive', 
          'forestgreen', 'royalblue', 'indigo', 'navy', 'mediumpurple', 'chocolate',
          'gold', 'darkorange', 'seagreen', 'turquoise', 'steelblue', 'slategray', 
          'peru', 'midnightblue', 'slateblue', 'dimgray', 'cadetblue', 'tomato'
         ]

def plot_predictions(name_, pred, actual):
    df = pd.DataFrame({'prediction': pred, 'actual': y_test})
    df = df.sort_values(by='actual').reset_index(drop=True)

    plt.figure(figsize=(11, 8))
    plt.scatter(df.index, df['prediction'], marker='x', color='r')
    plt.scatter(df.index, df['actual'], alpha=0.7, marker='o', color='black')
    plt.title(name_, fontsize=15)
    plt.legend(['prediction', 'actual'], fontsize=12)
    plt.show()

def mse_eval(name_, pred, actual):
    global my_predictions, colors, my_pred, my_actual, my_name
    
    my_name = name_
    my_pred = pred
    my_actual = actual

    plot_predictions(name_, pred, actual)

    mse = mean_squared_error(pred, actual)
    my_predictions[name_] = mse

    y_value = sorted(my_predictions.items(), key=lambda x: x[1], reverse=True)
    
    df = pd.DataFrame(y_value, columns=['model', 'mse'])
    print(df)
    min_ = df['mse'].min() - 10
    max_ = df['mse'].max() + 10
    
    length = len(df) / 2
    
    plt.figure(figsize=(9, length))
    ax = plt.subplot()
    ax.set_yticks(np.arange(len(df)))
    ax.set_yticklabels(df['model'], fontsize=12)
    bars = ax.barh(np.arange(len(df)), df['mse'], height=0.3)
    
    for i, v in enumerate(df['mse']):
        idx = np.random.choice(len(colors))
        bars[i].set_color(colors[idx])
        ax.text(v + 2, i, str(round(v, 3)), color='k', fontsize=12, fontweight='bold', verticalalignment='center')
        
    plt.title('MSE Error', fontsize=16)
    plt.xlim(min_, max_)
    
    plt.show()
    
def add_model(name_, pred, actual):
    global my_predictions, my_pred, my_actual, my_name
    my_name = name_
    my_pred = pred
    my_actual = actual
    
    mse = mean_squared_error(pred, actual)
    my_predictions[name_] = mse

def remove_model(name_):
    global my_predictions
    try:
        del my_predictions[name_]
    except KeyError:
        return False
    return True

def plot_all():
    global my_predictions, my_pred, my_actual, my_name
    
    plot_predictions(my_name, my_pred, my_actual)
    
    y_value = sorted(my_predictions.items(), key=lambda x: x[1], reverse=True)
    
    df = pd.DataFrame(y_value, columns=['model', 'mse'])
    print(df)
    min_ = df['mse'].min() - 10
    max_ = df['mse'].max() + 10
    
    length = len(df) / 2
    
    plt.figure(figsize=(9, length))
    ax = plt.subplot()
    ax.set_yticks(np.arange(len(df)))
    ax.set_yticklabels(df['model'], fontsize=12)
    bars = ax.barh(np.arange(len(df)), df['mse'], height=0.3)
    
    for i, v in enumerate(df['mse']):
        idx = np.random.choice(len(colors))
        bars[i].set_color(colors[idx])
        ax.text(v + 2, i, str(round(v, 3)), color='k', fontsize=12, fontweight='bold', verticalalignment='center')
        
    plt.title('MSE Error', fontsize=16)
    plt.xlim(min_, max_)
    
    plt.show()

# %%
from xgboost import plot_importance
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score, confusion_matrix

# %%
xgb = XGBClassifier()

params = {
    'n_estimators' : [100, 200, 300],
    'max_depth' : [4, 6, 8, 10, 12],
    'min_samples_leaf' : [3, 5, 6, 7, 10],
    'min_samples_split' : [2, 3, 5, 7, 10]
}
xgb_grid = GridSearchCV(xgb, param_grid = params, scoring="accuracy", n_jobs= -1, verbose = 1)
xgb_grid.fit(train_x, train_y)
# Out:
# Fitting 5 folds for each of 375 candidates, totalling 1875 fits
# [21:21:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:576:
# Parameters: { "min_samples_leaf", "min_samples_split" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [21:21:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
def metrics(y_test, pred):
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred)
    recall = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)
    roc_score = roc_auc_score(y_test, pred)
    print('정확도 : {0:.2f}, 정밀도 : {1:.2f}, 재현율 : {2:.2f}'.format(accuracy, precision, recall))
    print('f1-score : {0:.2f}, auc : {1:.2f}'.format(f1, roc_score))

# %%
print("최고 평균 정확도 : {0:.4f}".format(xgb_grid.best_score_))
print("최고의 파라미터 : ", xgb_grid.best_params_)
# Out:
# 최고 평균 정확도 : 0.8203
# 최고의 파라미터 :  {'max_depth': 12, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 100}

# %%
result = pd.DataFrame(xgb_grid.cv_results_)
result.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_max_depth', 'param_min_samples_leaf', 'param_min_samples_split',
#        'param_n_estimators', 'params', 'split0_test_score',
#        'split1_test_score', 'split2_test_score', 'split3_test_score',
#        'split4_test_score', 'mean_test_score', 'std_test_score',
#        'rank_test_score'],
#       dtype='object')

# %%
result.sort_values(by=['rank_test_score'], inplace=True)

# %%
model = xgb_grid.best_estimator_
pred = model.predict(val_x)
acc = accuracy_score(val_y, pred)
print("정확도 : {0:.4f}".format(acc))
# Out:
# 정확도 : 0.7222

# %%
prediction = np.where(prediction > 0.5, 1, 0)
submission = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": prediction
    })

submission.to_csv('submission.csv', index=False)

# %%
submission = pd.read_csv('submission.csv')
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         0
